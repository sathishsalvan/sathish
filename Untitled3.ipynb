# %%
a=25
b=5
pow(a,b)
# Out:
# 9765625

# %%
for i in range(1, 100,1):
   print(num, 'x', i, '=', num*i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2a44c7ca0e57> in <module>
#       1 for i in range(1, 100,1):
# ----> 2    print(num, 'x', i, '=', num*i)
#
# NameError: name 'num' is not defined

# %%
num=7
for i in range(1, 10000000):
   print(num, 'x', i, '=', num*i)
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 7 x 11 = 77
# 7 x 12 = 84
# 7 x 13 = 91
# 7 x 14 = 98
# 7 x 15 = 105
# 7 x 16 = 112
# 7 x 17 = 119
# 7 x 18 = 126
# 7 x 19 = 133
# 7 x 20 = 140
# 7 x 21 = 147
# 7 x 22 = 154
# 7 x 23 = 161
# 7 x 24 = 168
# 7 x 25 = 175
# 7 x 26 = 182
# 7 x 27 = 189
# 7 x 28 = 196
# 7 x 29 = 203
# 7 x 30 = 210
# 7 x 31 = 217
# 7 x 32 = 224
# 7 x 33 = 231
# 7 x 34 = 238
# 7 x 35 = 245
# 7 x 36 = 252
# 7 x 37 = 259
# 7 x 38 = 266
# 7 x 39 = 273
# 7 x 40 = 280
# 7 x 41 = 287
# 7 x 42 = 294
# 7 x 43 = 301
# 7 x 44 = 308
# 7 x 45 = 315
# 7 x 46 = 322
# 7 x 47 = 329
# 7 x 48 = 336
# 7 x 49 = 343
# 7 x 50 = 350
# 7 x 51 = 357
# 7 x 52 = 364
# 7 x 53 = 371
# 7 x 54 = 378
# 7 x 55 = 385
# 7 x 56 = 392
# 7 x 57 = 399
# 7 x 58 = 406
# 7 x 59 = 413
# 7 x 60 = 420
# 7 x 61 = 427
# 7 x 62 = 434
# 7 x 63 = 441
# 7 x 64 = 448
# 7 x 65 = 455
# 7 x 66 = 462
# 7 x 67 = 469
# 7 x 68 = 476
# ...
